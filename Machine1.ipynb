# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
df=df.iloc[0:10,:]
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           10 non-null     float64
#  1   latitude            10 non-null     float64
#  2   housing_median_age  10 non-null     float64
#  3   total_rooms         10 non-null     float64
#  4   total_bedrooms      10 non-null     float64
#  5   population          10 non-null     float64
#  6   households          10 non-null     float64
#  7   median_income       10 non-null     float64
#  8   median_house_value  10 non-null     float64
# dtypes: float64(9)
# memory usage: 848.0 bytes

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.jointplot(x='total_rooms',y='population',data=df, kind='reg');

# %%
from sklearn.linear_model import LinearRegression

# %%
X=df[["total_rooms"]]

# %%
X.head()
# Out:
#    total_rooms
# 0       5612.0
# 1       7650.0
# 2        720.0
# 3       1501.0
# 4       1454.0

# %%
Y=df[["population"]]

# %%
Y.head()
# Out:
#    population
# 0      1015.0
# 1      1129.0
# 2       333.0
# 3       515.0
# 4       624.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['population'].plot(kind='hist', bins=20, title='population')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['population'].plot(kind='line', figsize=(8, 4), title='population')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
reg= LinearRegression()
model = reg.fit(X,Y)

# %%
model
# Out:
# LinearRegression()

# %%
str(model)
# Out:
# 'LinearRegression()'

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
# ...

# %%
#b0
model.intercept_
# Out:
# array([513.41544463])

# %%
#b1
model.coef_
# Out:
# array([[0.18672899]])

# %%
#rkare
model.score(X,Y)
# Out:
# 0.2676372244963562

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.regplot(x="housing_median_age", y="population",data=df, ci=None, scatter_kws={'color':'r','s':9});
g.set_title('population vs housing_median_age= 513,4+ Y*0,18');
g.set_ylabel("population");
g.set_xlabel("housing_median_age");
plt.xlim(0,20);
plt.ylim(0,5000);

# %%
513.4+0.18*720
# Out:
# 643.0

# %%
model.predict([[720]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[647.86031733]])

# %%
model.intercept_ + model.coef_*720
# Out:
# array([[647.86031733]])

# %%
new_datas=[[720],[5612],[170],[330],[340]]

# %%
model.predict(new_datas)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 647.86031733],
#        [1561.33853571],
#        [ 545.15937291],
#        [ 575.03601129],
#        [ 576.90330119]])

# %%
real_y= Y[0:10]

# %%
prediction = pd.DataFrame(model.predict(X)[0:10])

# %%
error= pd.concat([real_y,prediction],axis=1)

# %%
error.columns=['real_y','prediction']

# %%
error
# Out:
#    real_y   prediction
# 0  1015.0  1561.338536
# 1  1129.0  1941.892217
# 2   333.0   647.860317
# 3   515.0   793.695658
# 4   624.0   784.919396
# 5   671.0   772.408554
# 6  1841.0  1056.236618
# 7   375.0   665.039384
# 8  3134.0  1407.660577
# 9   787.0   792.948742

# %%
error["error"]=error["real_y"]-error["prediction"]

# %%
error
# Out:
#    real_y   prediction        error
# 0  1015.0  1561.338536  -546.338536
# 1  1129.0  1941.892217  -812.892217
# 2   333.0   647.860317  -314.860317
# 3   515.0   793.695658  -278.695658
# 4   624.0   784.919396  -160.919396
# 5   671.0   772.408554  -101.408554
# 6  1841.0  1056.236618   784.763382
# 7   375.0   665.039384  -290.039384
# 8  3134.0  1407.660577  1726.339423
# 9   787.0   792.948742    -5.948742

# %%
import numpy as np

# %%
MSE=np.mean(error["error"])

# %%
MSE
# Out:
# -9.094947017729283e-14

# %%
from math import sqrt
RMSE= sqrt(abs(MSE))

# %%
RMSE
# Out:
# 3.015782985847835e-07
